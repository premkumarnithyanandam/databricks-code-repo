# %%
# %fs ls /Volumes/workspace/default/usage_metrics/

# %%
# %py
import requests
variable=requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")


dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",variable.text,overwrite=True)

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header=True)
df1.show(5)

# %%
# %pip install pandas

# %%
# %python
import pandas as pd

pdf = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
pdf.head()

# %%
import pandas as pd
pdf1=pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

display(pdf1)

# %%
def upper(x):
	return x.upper()

upper("prem")

# %%
spark.sql("select * from default.mobile_os_usage").show()

# %%
# %python
spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv").write.saveAsTable("default.mobile_os_usage")
