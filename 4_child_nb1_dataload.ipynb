# %%
# %pycat
import requests
variable=requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
dbutils.fs.put("/Volumes/workspace/default/usage_metrics_test/mobile_os_usage.csv",variable.text,overwrite=True)
