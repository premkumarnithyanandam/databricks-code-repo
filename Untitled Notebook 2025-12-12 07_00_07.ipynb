# %%
# %pip install pandas

# %%
# %py
import pandas as pd
pdf1=pd.read_csv("/Volumes/workspace/default/usage_metrics_test/mobile_os_usage.csv")
display(pdf1)

# %%
# %fs ls /Volumes/workspace/default/usage_metrics_test

# %%
# %run "/Workspace/Users/premkumarnithyanandam@gmail.com/databricks-code-repo/4_child_nb1_dataload"

# %%
df2=spark.read.csv("/Volumes/workspace/default/usage_metrics_test/mobile_os_usage.csv",header=True,inferSchema=True)
df2.show(3)

# %%
# %py 
df2.write.saveAsTable("default.mobile_os_usage3")

# %%
# %sql
create volume if not exists workspace.default.usage_metrics_test;

# %%
# %sh 
echo "task completed"

# %%
echo "task"
